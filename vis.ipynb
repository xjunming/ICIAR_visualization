# %%
from PIL import Image
import matplotlib.pyplot as plt

def vis_acc(filename='./classify/class_0'):
    with open(filename) as f:
        i = 0
        line = f.readline()
        while line:
            im = Image.open(str(line).rstrip('\n'))
            plt.subplot(9,9,1+i)
            plt.axis('off')
            plt.imshow(im)
            line = f.readline()
            if i >=80:
                break
            i = i+1
    plt.show()

# %%
def count_f(filename):
    with open(filename) as f:
        i = 0
        line = f.readline()
        while line:
            line = f.readline()
            i = i+1
    return i

# %%
files = [
    './classify/class_0','./classify/class_1',
    './classify/class_2','./classify/class_3',
    './classify/class_4'
]
for file in files:
    print(file,'has %i pics'%count_f(file))
# Out:
# ./classify/class_0 has 34 pics
# ./classify/class_1 has 160 pics
# ./classify/class_2 has 26 pics
# ./classify/class_3 has 104 pics
# ./classify/class_4 has 76 pics

# %%
vis_acc('./classify/class_0')

# %%
vis_acc('./classify/class_1')

# %%
vis_acc('./classify/class_2')

# %%
vis_acc('./classify/class_3')

# %%
vis_acc('./classify/class_4')
